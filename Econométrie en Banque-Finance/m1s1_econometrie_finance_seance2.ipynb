# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
# <b><center><font size="6">Travaux Dirigés - Econométrie en finance - séance 2 </font></center></b>
#
#
#
# <g><h7><center> CM - P. Durand  - pierre.durand@u-pec.fr </center></h7></g>
#
# <g><h7><center> TD - A. Birem  - abderraouf.birem@etu.u-pec.fr </center></h7></g>
#
#
# <b><center><font size="5">M1 - 2023-2024</font></center></b>
#
#
#
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# <hr style=" border: 2.5px solid black;">
#
#
# <b>Objectifs de la séance : </b>
#
# - Révision des outils de bases vus en première séance
# - Bases de données sous python :
#     - importation et sauvegarde
#     - manipulation de variables (création, suppréssion, compbinaison,...)
#     - statistiques descriptives
#
#
#
# </span>

# %% [markdown]
# <hr style=" border: .5px solid black;">
# <br>
#
#
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# <b>Exercice 1 - Révision sur les bases  </b>
#
# On fait un premier exercice pour se remémorer ce qui a été vu en première séance.
#
# 1. Créez des variables en donnant un nom logique pour :
#     - un `int`
#     - un `str`
#     - un `float`
#     - une `list` (avec quelques `int` ou `float`)
#
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# 2. Une liste est créée dans la cellule suivante. Elle contient des `int` et des `str`. Créez une boucle permettant de compter le nombre d'éléments qui sont des `int` et le nombre d'éléments qui sont des `str`.
#
#
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# 2. Deux listes sont données :
# - `l1` qui contient des chaînes de caractère
# - `l2` qui contient des entiers
#
# Créez une boucle permettant de stocker dans une nouvelle liste (`l3` par exemple) les éléments de `l1`, en respectant les consignes suivantes :
# - dans la boucle, parcourrez `l2`
# - si l'élément `n` de `l2` est paire, ajoutez le $n$ème élément de `l1` à `l3`
# - sinon rien
#
# Enfin, affichez `l3`.
#
# _Note_ : Rappelez de `.append()` et de `%`.
#
# </span>

# %% [markdown]
# <hr style=" border: .5px solid black;">
# <br>
#
#
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# <b>Exercice 2 - Importer une base de données : .xlsx et .txt  </b>
#
# Vous trouverez dans la DropBox, deux bases de données :
# - salaireprod.txt
# - cointegration.xlsx
#
#
# 1. Téléchargez les deux bases et mettez les dans un dossier dont vous connaissez l'emplacement
#
# <br>
#
# 2. Importez le package permettant de manipuler des données sous python
#
# <br>
#
# 3. À l'aide des fonctions adéquates, téléchargez les deux bases sous python :
#  - salaireprod.txt doit être téléchargée avec `.read_csv()` (attention au séparateur), sous le nom `df1`
#  - cointegration.xlsx doit être téléchargée avec `.read_excel()`,  sous le nom `df2`
#
# </span>

# %%
import pandas as pd

# %%
chemin = "C:\\Users\\issak\\Documents\\M1\\Econométrie en Banque-Finance\\data(1)\\"

# %%
df1 = pd.read_csv(chemin+'salaireprod.txt', sep = "\t")
df1
# Out:
#     Years  wages  productivity
# 0    1959   58.5          47.2
# 1    1960   59.9          48.0
# 2    1961   61.7          49.8
# 3    1962   63.9          52.1
# 4    1963   65.3          54.1
# 5    1964   67.8          54.6
# 6    1965   69.3          58.6
# 7    1966   71.8          61.0
# 8    1967   73.7          62.3
# 9    1968   76.5          64.5
# 10   1969   77.6          64.8
# 11   1970   79.0          66.2
# 12   1971   80.5          68.8
# 13   1972   82.9          71.0
# 14   1973   84.7          73.1
# 15   1974   83.7          72.2
# 16   1975   84.5          74.8
# 17   1976   87.0          77.2
# 18   1977   88.1          78.4
# 19   1978   89.7          79.5
# 20   1979   90.0          79.7
# 21   1980   89.7          79.8
# 22   1981   89.8          81.4
# 23   1982   91.1          81.2
# 24   1983   91.2          84.0
# 25   1984   91.5          86.4
# 26   1985   92.8          88.1
# 27   1986   95.9          90.7
# 28   1987   96.3          91.3
# 29   1988   97.3          92.4
# 30   1989   95.8          93.3
# 31   1990   96.4          94.5
# 32   1991   97.4          95.9
# 33   1992  100.0         100.0
# 34   1993   99.9         100.1
# 35   1994   99.7         101.4
# 36   1995   99.1         102.2
# 37   1996   99.6         105.2
# 38   1997  101.1         107.5
# 39   1998  105.1         110.5

# %%
df2 = pd.read_excel(chemin+'cointegration.xlsx')
df2
# Out:
#     date    Lconso      Lrev
# 0   1960  2.522103  1.495855
# 1   1961  2.546667  1.528894
# 2   1962  2.577572  1.588945
# 3   1963  2.607843  1.636724
# 4   1964  2.631128  1.672966
# 5   1965  2.647627  1.704199
# 6   1966  2.667999  1.737875
# 7   1967  2.689163  1.774625
# 8   1968  2.707497  1.815373
# 9   1969  2.734721  1.865320
# 10  1970  2.753994  1.916873
# 11  1971  2.777715  1.963571
# 12  1972  2.799572  2.012193
# 13  1973  2.823137  2.067717
# 14  1974  2.835262  2.139785
# 15  1975  2.843790  2.200817
# 16  1976  2.866924  2.251279
# 17  1977  2.878030  2.301501
# 18  1978  2.894780  2.362498
# 19  1979  2.909389  2.410484
# 20  1980  2.914545  2.465212
# 21  1981  2.923375  2.527231
# 22  1982  2.937463  2.585855
# 23  1983  2.941230  2.625347
# 24  1984  2.944303  2.653836
# 25  1985  2.952614  2.683283
# 26  1986  2.968667  2.706853
# 27  1987  2.982712  2.726187
# 28  1988  2.996845  2.751877
# 29  1989  3.010535  2.783149
# 30  1990  3.021330  2.812207
# 31  1991  3.023859  2.828571
# 32  1992  3.028069  2.849240
# 33  1993  3.027894  2.856908
# 34  1994  3.034990  2.863292
# 35  1995  3.041975  2.876563
# 36  1996  3.049992  2.887816
# 37  1997  3.052778  2.898373
# 38  1998  3.069814  2.913199
# 39  1999  3.084768  2.924433
# 40  2000  3.100283  2.949234
# 41  2001  3.110968  2.971440
# 42  2002  3.118873  2.988734
# 43  2003  3.126119  2.999526
# 44  2004  3.135233  3.018083
# 45  2005  3.146320  3.031887
# 46  2006  3.155807  3.053522
# 47  2007  3.166274  3.076215
# 48  2008  3.168303  3.090372
# 49  2009  3.168624  3.090939
# 50  2010  3.176102  3.102820
# 51  2011  3.177998  3.111239
# 52  2012  3.176907  3.115574
# 53  2013  3.178956  3.113284
# 54  2014  3.182001  3.118963
# 55  2015  3.188036  3.123764
# 56  2016  3.197702  3.131468

# %% [markdown]
# <hr style=" border: .5px solid black;">
# <br>
#
#
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# <b>Exercice 3 - Manipulation des données  </b>
#
# 1. Pour chacune des bases de données (`df1` et `df2`), et à l'aide des fonctions vues en cours :
#
#     a. Affichez les 8 premières lignes
#
#     b. Affichez les dimansions des bases
#
#     c. Affichez la liste des colonnes
#
#     d. On remarque que cette liste est de type `list`. À l'aide des inices, afficher les noms des deuxièmes colonnes.
#
#     e. Affichez les deuxièmes colonnes des dataframes
#
#     f. Affichez les deuxièmes colonnes pour des valeurs supérieurs à $60$
#
# </span>

# %%
df1.head(8)
# Out:
#    Years  wages  productivity
# 0   1959   58.5          47.2
# 1   1960   59.9          48.0
# 2   1961   61.7          49.8
# 3   1962   63.9          52.1
# 4   1963   65.3          54.1
# 5   1964   67.8          54.6
# 6   1965   69.3          58.6
# 7   1966   71.8          61.0

# %%
df1.tail(8)
# Out:
#     Years  wages  productivity
# 32   1991   97.4          95.9
# 33   1992  100.0         100.0
# 34   1993   99.9         100.1
# 35   1994   99.7         101.4
# 36   1995   99.1         102.2
# 37   1996   99.6         105.2
# 38   1997  101.1         107.5
# 39   1998  105.1         110.5

# %%
df1.shape
# Out:
# (40, 3)

# %%
df1.columns
# Out:
# Index(['Years', 'wages', 'productivity'], dtype='object')

# %%
df1.columns[1]
# Out:
# 'wages'

# %%
df1[df1.columns[1]]
# Out:
# 0      58.5
# 1      59.9
# 2      61.7
# 3      63.9
# 4      65.3
# 5      67.8
# 6      69.3
# 7      71.8
# 8      73.7
# 9      76.5
# 10     77.6
# 11     79.0
# 12     80.5
# 13     82.9
# 14     84.7
# 15     83.7
# 16     84.5
# 17     87.0
# 18     88.1
# 19     89.7
# 20     90.0
# 21     89.7
# 22     89.8
# 23     91.1
# 24     91.2
# 25     91.5
# 26     92.8
# 27     95.9
# 28     96.3
# 29     97.3
# 30     95.8
# 31     96.4
# 32     97.4
# 33    100.0
# 34     99.9
# 35     99.7
# 36     99.1
# 37     99.6
# 38    101.1
# 39    105.1
# Name: wages, dtype: float64

# %%
df1[df1['wages']>60]
# Out:
#     Years  wages  productivity
# 2    1961   61.7          49.8
# 3    1962   63.9          52.1
# 4    1963   65.3          54.1
# 5    1964   67.8          54.6
# 6    1965   69.3          58.6
# 7    1966   71.8          61.0
# 8    1967   73.7          62.3
# 9    1968   76.5          64.5
# 10   1969   77.6          64.8
# 11   1970   79.0          66.2
# 12   1971   80.5          68.8
# 13   1972   82.9          71.0
# 14   1973   84.7          73.1
# 15   1974   83.7          72.2
# 16   1975   84.5          74.8
# 17   1976   87.0          77.2
# 18   1977   88.1          78.4
# 19   1978   89.7          79.5
# 20   1979   90.0          79.7
# 21   1980   89.7          79.8
# 22   1981   89.8          81.4
# 23   1982   91.1          81.2
# 24   1983   91.2          84.0
# 25   1984   91.5          86.4
# 26   1985   92.8          88.1
# 27   1986   95.9          90.7
# 28   1987   96.3          91.3
# 29   1988   97.3          92.4
# 30   1989   95.8          93.3
# 31   1990   96.4          94.5
# 32   1991   97.4          95.9
# 33   1992  100.0         100.0
# 34   1993   99.9         100.1
# 35   1994   99.7         101.4
# 36   1995   99.1         102.2
# 37   1996   99.6         105.2
# 38   1997  101.1         107.5
# 39   1998  105.1         110.5

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# 2. Nous rappelons les éléments suivant :
#
#     - la fonction `.shift(1)` appliquée à un dataframe permet de décaler une colonne d'une période
#     - un taux de croissance se calcul comme suit : soit $X_t$ une variable qui évolue dans le temps, alors
#
# $$\frac{X_t - X_{t-1}}{X_{t-1}} \cdot 100 = \left(\frac{X_t}{X_{t-1}} - 1\right) \cdot 100$$
# est son taux de croissance.
#
# Créez une nouvelle colonne avec le taux de croissance de chaque variable pour df1. Les noms des nouvelles colonnes sera celui des anciennes auxquels on ajoute `"_gr"` (pour growth rate).
# </span>

# %%
df1['wages_gr']=((df1['wages']/df1['wages'].shift(1))-1)*100
df1['productivity_gr']=((df1['productivity']/df1['productivity'].shift(1))-1)*100
df1
# Out:
#     Years  wages  productivity  wages_gr  productivity_gr
# 0    1959   58.5          47.2       NaN              NaN
# 1    1960   59.9          48.0  2.393162         1.694915
# 2    1961   61.7          49.8  3.005008         3.750000
# 3    1962   63.9          52.1  3.565640         4.618474
# 4    1963   65.3          54.1  2.190923         3.838772
# 5    1964   67.8          54.6  3.828484         0.924214
# 6    1965   69.3          58.6  2.212389         7.326007
# 7    1966   71.8          61.0  3.607504         4.095563
# 8    1967   73.7          62.3  2.646240         2.131148
# 9    1968   76.5          64.5  3.799186         3.531300
# 10   1969   77.6          64.8  1.437908         0.465116
# 11   1970   79.0          66.2  1.804124         2.160494
# 12   1971   80.5          68.8  1.898734         3.927492
# 13   1972   82.9          71.0  2.981366         3.197674
# 14   1973   84.7          73.1  2.171291         2.957746
# 15   1974   83.7          72.2 -1.180638        -1.231190
# 16   1975   84.5          74.8  0.955795         3.601108
# 17   1976   87.0          77.2  2.958580         3.208556
# 18   1977   88.1          78.4  1.264368         1.554404
# 19   1978   89.7          79.5  1.816118         1.403061
# 20   1979   90.0          79.7  0.334448         0.251572
# 21   1980   89.7          79.8 -0.333333         0.125471
# 22   1981   89.8          81.4  0.111483         2.005013
# 23   1982   91.1          81.2  1.447661        -0.245700
# 24   1983   91.2          84.0  0.109769         3.448276
# 25   1984   91.5          86.4  0.328947         2.857143
# 26   1985   92.8          88.1  1.420765         1.967593
# 27   1986   95.9          90.7  3.340517         2.951192
# 28   1987   96.3          91.3  0.417101         0.661521
# 29   1988   97.3          92.4  1.038422         1.204819
# 30   1989   95.8          93.3 -1.541624         0.974026
# 31   1990   96.4          94.5  0.626305         1.286174
# 32   1991   97.4          95.9  1.037344         1.481481
# 33   1992  100.0         100.0  2.669405         4.275287
# 34   1993   99.9         100.1 -0.100000         0.100000
# 35   1994   99.7         101.4 -0.200200         1.298701
# 36   1995   99.1         102.2 -0.601805         0.788955
# 37   1996   99.6         105.2  0.504541         2.935421
# 38   1997  101.1         107.5  1.506024         2.186312
# 39   1998  105.1         110.5  3.956479         2.790698

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# 3. Oups ! Le taux de croissance de la variable `"Years"` ne sert à rien... Retirons cette variable avant d'enregistrer la nouvelle base de données.
#
# _Note_ : on utilisera la fonction `.drop()`.
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# 4. Cette fois-ci, on est bon. On peut désormais enregistrer notre travail !
# </span>

# %% [markdown]
# <hr style=" border: .5px solid black;">
# <br>
#
#
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# <b>Exercice 4 - Statistiques descriptives  </b>
#
# 1. En faisant la recherche sur internet `axis label scatter matplotlib`, inspirez-vous du forum stack overflow pour faire les nuages de points (avec noms sur les axes et un titre) pour les couples de variables suivants :
#     - df1 : "wages" et "productivity"
#     - df2 : "Lconso" et "Lrev"
#
# Commentez les nuages de points
#
# </span>

# %%
import matplotlib.pyplot as plt

# %%
df1['wages'].plot()
# Out:
# <Axes: >

# %%
plt.scatter(df1['wages'] , df1['productivity'])

# %%
plt.scatter(df2['Lconso'] , df2['Lrev'])

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
#
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# 2. En vous inspirant des commandes utilisées pour le nuage de points, proposez un graphique pour les 4 variables, permettant de voir leur évolution dans le temps. En utilisant la commande `plt.savefig()`, vous sauvegarderez vos graphiques (et en mettant en argument le nom que vous voulez donner au graphique).
#
#
# _Note_ : la fonction à utiliser n'est pas `.scatter()` mais `.plot()`.
#
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# 3. Affichez le tableau de corrélations entre "wages" et "productivity" de df1. Puis le tableau des corrélations avec les taux de croissances de ces deux variables. Commentez.
#
# </span>

# %%
['wages', 'productivity']
# Out:
# ['wages', 'productivity']

# %%
df1[['wages', 'productivity']].corr()
# Out:
#                  wages  productivity
# wages         1.000000      0.979325
# productivity  0.979325      1.000000

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# 4. Une commande vue en cours permet d'afficher les principales statistiques descriptives des variables d'un dataframe. Affichez les pour df1 puis Commentez.
#
# </span>

# %%
df1.describe()
# Out:
#              Years       wages  productivity   wages_gr  productivity_gr
# count    40.000000   40.000000     40.000000  39.000000        39.000000
# mean   1978.500000   85.645000     78.595000   1.523806         2.217918
# std      11.690452   12.956316     17.839885   1.456791         1.647754
# min    1959.000000   58.500000     47.200000  -1.541624        -1.231190
# 25%    1968.750000   77.325000     64.725000   0.375775         1.089423
# 50%    1978.500000   89.700000     79.600000   1.447661         2.131148
# 75%    1988.250000   96.325000     92.625000   2.657822         3.328416
# max    1998.000000  105.100000    110.500000   3.956479         7.326007

# %% [markdown]
# <hr style=" border: .5px solid black;">
# <br>
#
#
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# <b>Exercice 5 - Tout de A à Z  </b>
#
# Nous souhaiterions étudier l'évolution de l'indice boursier CAC40. À l'aide des différents outils mobilisés dans ce TD, rendez-vous sur le site de <a href="https://fr.finance.yahoo.com/?guccounter=1&guce_referrer=aHR0cHM6Ly93d3cuZ29vZ2xlLmNvbS8&guce_referrer_sig=AQAAABp6_pkXMwulsm0y4B8Pr3Haq_-44HDvLzhUsxELsbq59fqItG8VLMRNdQJL2xsiw9jDKfGIohuho5X2VYyXFhNi05a6fLNfPH5rMg6bDLEiK8rOJf4qBMJHgVs41hmZFcwrFP-mVHWXUXrg2CN72jfFJBh6JZ_8O6yIJXODD5eo">Yahoo Finance</a> afin de télécharger l'historique des données du CAC40 en fréqeunce mensuelle depuis octobre 2000.
#
# Importez ensuite ces données sous python (attention de bien vérifier le format des données) et menez une courte étude graphique et statisitque appropriée.
#
#
# </span>
