# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
# <b><center><font size="6">Contrôle continu 1 - Econométrie en finance</font></center></b>
#
# <b><center><font size="5"> Sujet 1</font></center></b>
#
# <g><h7><center> CM - P. Durand  - pierre.durand@u-pec.fr </center></h7></g>
#
# <g><h7><center> TD - R.Birem  - abderraouf.birem@u-pec.fr </center></h7></g>
#
#
# <b><center><font size="5">M1 - 2024-2025</font></center></b>
#
#
#
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# <b><center><font size="5">Insérez votre Nom, Prénom et Numéro d`étudiant. Pensez a exécuter toutes les cellulles ci-dessous</font></center></b>
#
# </span>

# %%
#Nom : KACHAOU
#Prénom : Issa

# %%
Num_Etudiant=21905943

# %%
Vars = ['Adidas', 'Allianz', 'BASF', 'Bayer', 'BMW', 'Deutsche Bank',
       'Deutsche Telekom', 'SAP', 'Siemens', 'Volkswagen']

# %%
import random
def convert_to_range(number):
    if len(str(number)) != 8:
        return 
    random.seed(number)
    result = random.randint(0, 10)
    return result
code = convert_to_range(Num_Etudiant)
var = Vars[code]
var
# Out:
# 'Adidas'

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# <hr style=" border: 2.5px solid black;">
#
#
# Epreuves :
#
# - trois exercices : codes / cours / interprétation
# - <b>répondez sur le Notebook</b>
# - durée de l'épreuve : <b>1h20</b>
#
#
#
# <br>
#
#
#
#
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# <hr style=" border: 2.5px solid black;">
#
#
# <b>Exercice 1 : Corrigez les erreurs dans les codes ci-dessous afin qu'ils s'exécutent correctement. (3 pts)</b>
#
#
#
# </span>

# %%
import matplotlib_pyplot from plt

# %%
liste = ['Envie', 'de', 'goûter', 'au', 'vent,',
         'étouffé', 'par', 'le', 'temps', 
         'Rien', "n'est", 'plus', 'comme', 'avant,', 
         'un', 'peu', 'comme', 'les', 'gens']

#Pour compter le Nombre de "a" et de "e" dans cette liste nous exécutons cette boucle, corrigez là: 

# Initialiser les compteurs
count_e = 0
count_a = 0

# Boucle pour compter 'e' et 'a'
for word in liste:
    for letter in word:  # Boucle à travers chaque lettre dans le mot
        if letter == 'e': # correction : changement de ; par :  
            count_e = count_e + 1
#correction de l'erreur d'indentation  avec  le elif au même niveau que le if#
        elif letter == 'a':
            count_a += 1

print("Nombre de 'e' :", count_e)
print("Nombre de 'a' :", count_a)
# Out:
# Nombre de 'e' : 13
# Nombre de 'a' : 4

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# <hr style=" border: 2.5px solid black;">
#
#
# <b>Exercice 2 : question de cours (3 pts)</b>
#
#
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
# Rappelez l'hypothèse nulle ainsi que l'hypothèse alternative du test de significativité individuelle (test de Student), ainsi que la règle de décision avec un seuil de risque de **1%**
#
#
# </span>

# %% [markdown]
# $HO: \text{hypothèse nulle} : \widehat{\beta_i} = 0 \,vs\, HA :\text{hypothèse alternative}: \widehat{\beta_i} \neq 0$
#
# Si $|𝑡𝛽̂ 𝑖|≤𝑡𝑝/2$, on ne rejette pas l'hypothèse nulle, La variable $𝑋𝑖$ est dite non statistiquement significative
#
# Si $|𝑡𝛽̂ 𝑖|>𝑡𝑝/2$, on  rejette  l'hypothèse nulle, On dit alors que la variable est statistiquement significative.

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# On suppose que l’hypothèse d’homoscédasticité du terme d’erreur n’est pas vérifiée. Quel est l’effet de la violation de cette hypothèse (la conséquence) ?
#
# </span>

# %% [markdown]
# La violation de l’hypothèse d’homoscédasticité du terme d’erreur a pour effet de rendre faux les test de significativité statistiques. Par conséquent nous ne pouvons pas interpreter le modèle de manière rigoureuse.

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
# <hr style=" border: 2.5px solid black;">
# <b>Exercice 3 : application économétrique (14 pts)</b>
# <br>
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
#
# Le DAX (Deutscher Aktienindex) est l'indice boursier allemand qui reflète la performance des 40 plus grandes sociétés cotées à la Bourse de Francfort.
# Il est un baromètre clé de la santé économique en Allemagne et, plus largement, en Europe. Le DAX comprend des entreprises
# de divers secteurs, y compris des sociétés comme Siemens, BMW, Deutsche Bank, et Allianz.
#
# Dans cet exercice, nous allons analyser la relation entre la rentabilité de l'indice phare DAX et celle des entreprises qui le composent.
# Nous examinerons comment la performance financière de DAX influe sur le entreprises et comment les événements mondiaux
# impactent les cours d'actions.
#
# Nous avons également deux variables binaires dont nous voulons étudier l'effet sur la rentabilité du DAX :
#
# - WAR : une variable indicatrice de la Guerre russo-ukrainienne. Elle vaut 0 pour toutes les périodes avant la guerre et 1 pendant.
# - COVID : une dummy variable qui vaut 0 avant la pandémie et 1 au début de la pandémie de COVID-19.
#
# Votre tâche est de répondre aux questions ci-dessous et d'effectuer les analyses nécessaires en utilisant les données fournies.
#
#
#
#
# <br>
#
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# Rappellez l'interet de l'importation des librairies **Pandas**  et **Matplotlib.pyplot**
# <br>
#
# </span>

# %%
# Pandas est une librarie Python utilisée pour la manipulation de base de donnée sous le format dataframe
# matplotlib.pyplotest une librarie Python utilisée pour faire de la représentation graphique de nos statistiques

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# Complétez le code pour assurer la **bonne** l'importation de votre BDD
# <br>
#
# </span>

# %%
#Renseigner le chemin vers votre bdd
path = "C:\\Users\\issak\\Documents\\M1\\Econométrie en Banque-Finance\\data_2\\"
#Importation de la Bdd
base = pd.read_csv(path + "base.csv", sep = "*") #!!!!!!!!!!!!!!!!!!!

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
# La sous-base **df** fera l'objet de votre étude économétrique
#
#
#
# </span>

# %%
df = base[['Date', 'DAX', var]]
df
# Out:
#             Date           DAX      Adidas
# 0     2019-01-02  10580.190430  175.456146
# 1     2019-01-03  10416.660156  175.027954
# 2     2019-01-04  10767.690430  181.783600
# 3     2019-01-07  10747.809570  180.499084
# 4     2019-01-08  10803.980469  184.875977
# ...          ...           ...         ...
# 1267  2023-12-21  16687.419922  193.829056
# 1268  2023-12-22  16706.179688  183.580292
# 1269  2023-12-27  16742.070312  184.995987
# 1270  2023-12-28  16701.550781  183.540421
# 1271  2023-12-29  16751.640625  183.600235
#
# [1272 rows x 3 columns]

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# Afin de contrôler l'effet des événements ayant impacté l'économie allemande et européenne au cours des années précédentes, nous introduirons deux variables dummy pour indiquer s'il s'agit d'une période de crise sanitaire ou de guerre.
# <br>
#
# </span>

# %%
import warnings

# Ignorer les avertissements
warnings.filterwarnings('ignore')


# Assurer que la colonne 'Date' est au format datetime
df['Date'] = pd.to_datetime(df['Date'])

# Définir les périodes pour chaque événement
# Période de COVID-19 : début en mars 2020
covid_start = '2020-03-01'
covid_end = '2020-09-01'  # Fin approximative des mesures strictes


# Période de la guerre russo-ukrainienne : début en février 2022
war_start = '2022-02-01'
war_end = '2022-12-31'  # À ajuster selon les développements

# Créer les colonnes dummy
df['COVID'] = ((df['Date'] >= covid_start) & (df['Date'] <= covid_end)).astype(int)
df['War'] = ((df['Date'] >= war_start) & (df['Date'] <= war_end)).astype(int)

# %%
df.head()
# Out:
#         Date           DAX      Adidas  COVID  War
# 0 2019-01-02  10580.190430  175.456146      0    0
# 1 2019-01-03  10416.660156  175.027954      0    0
# 2 2019-01-04  10767.690430  181.783600      0    0
# 3 2019-01-07  10747.809570  180.499084      0    0
# 4 2019-01-08  10803.980469  184.875977      0    0

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
# En finance, on préfère les taux de croissance aux prix bruts car ils offrent une meilleure comparabilité entre entreprises et secteurs, indépendamment de leur taille. Les taux de croissance permettent d'analyser les tendances économiques sous-jacentes et d'évaluer la performance relative, facilitant ainsi la prise de décision d'investissement.
#
# **En vous servant de la formule ci-dessous, calculez les taux de croissance pour vos variables, sachant qu'aucun bon de trésor ni de taux d'intérêt à rembourser n'est inclus dans ce cas.**
#
#
#                                 df["rINDICE"] = 100 * ( df["INDICE"]/df["INDICE"].shift(1) - 1 )
#
# <br>
#
# </span>

# %%
df["rDAX"] = 100 * ( df["DAX"]/df["DAX"].shift(1) - 1 )

df["rAdidas"] = 100 * ( df["Adidas"]/df["Adidas"].shift(1) - 1 )

# %%
df
# Out:
#            Date           DAX      Adidas  COVID  War      rDAX   rAdidas
# 0    2019-01-02  10580.190430  175.456146      0    0       NaN       NaN
# 1    2019-01-03  10416.660156  175.027954      0    0 -1.545627 -0.244045
# 2    2019-01-04  10767.690430  181.783600      0    0  3.369893  3.859752
# 3    2019-01-07  10747.809570  180.499084      0    0 -0.184634 -0.706618
# 4    2019-01-08  10803.980469  184.875977      0    0  0.522626  2.424883
# ...         ...           ...         ...    ...  ...       ...       ...
# 1267 2023-12-21  16687.419922  193.829056      0    0 -0.272699 -0.775748
# 1268 2023-12-22  16706.179688  183.580292      0    0  0.112419 -5.287527
# 1269 2023-12-27  16742.070312  184.995987      0    0  0.214834  0.771159
# 1270 2023-12-28  16701.550781  183.540421      0    0 -0.242022 -0.786810
# 1271 2023-12-29  16751.640625  183.600235      0    0  0.299911  0.032589
#
# [1272 rows x 7 columns]

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# - Commentez l'intérêt de la fonction ***df.describe()***, en interprétant les résultats principaux qu'elle affiche (à la fois sur le plan statistique et économique).
#
#
# - Pourquoi avons-nous exclu la variable **Date** des résultats ?
# <br>
#
# </span>

# %%
df.describe().drop(columns=['Date'], errors='ignore')
# Out:
#                 DAX       Adidas        COVID          War         rDAX  \
# count   1272.000000  1272.000000  1272.000000  1272.000000  1271.000000
# mean   13847.340333   219.644311     0.100629     0.185535     0.044918
# std     1678.008091    53.617957     0.300955     0.388884     1.320958
# min     8441.709961    93.272156     0.000000     0.000000   -12.238615
# 25%    12593.712158   173.022488     0.000000     0.000000    -0.481808
# 50%    13831.899902   228.810692     0.000000     0.000000     0.088588
# 75%    15457.139648   267.689209     0.000000     0.000000     0.701218
# max    16794.429688   327.720154     1.000000     1.000000    10.975900
#
#            rAdidas
# count  1271.000000
# mean      0.029198
# std       2.273326
# min     -13.406374
# 25%      -1.099133
# 50%       0.000000
# 75%       1.092205
# max      21.383716

# %% [markdown]
# df.describe() nos donne l'ensemble des statistique descriptive de notre base.
#
# Nous avons exclu la variable date car connaitre l'année moyenne ou encore l'ecart type de l'année est inutile et surtout ne veut rien dire.

# %%
# Elle nous informe que la croissance du d'adidas en taux de croissante est plus volatile que celle du DAX 
# std dax : 1.320958 alors que std adidas : 2.273326
# Std : stardard deviation est l'ecart type

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# L'une des étapes clés de l'étude empirique repose sur l'analyse graphique des séries. Après avoir calculé vos taux de croissance. Quelle est la différence entre les deux graphiques projetés ci-dessous? **Commentez**
# <br>
#
# </span>

# %%
df.plot(x="Date", y="DAX", title="Évolution de l'indice DAX", figsize=(12, 6))
# Out:
# <Axes: title={'center': "Évolution de l'indice DAX"}, xlabel='Date'>

# %%
df.plot(x="Date", y="rDAX", title="Évolution de la rentabilité de l'indice DAX", figsize=(12, 6))
# Out:
# <Axes: title={'center': "Évolution de la rentabilité de l'indice DAX"}, xlabel='Date'>

# %% [markdown]
# L'évolution nominal du DAX nous montre que l'indice subit une tendance haussière sur l'ensemble de la période qui nous donnée. Cependant la croissance à connu des chutes notamement on peut voir le creux du covid début 2020, et une tendance baissière entre 2022 et 2023 avant une reprise en 2024

# %% [markdown]
# L'évolution de la du DAX en taux de croissance nos informe que la rentabilité de ford se situe globalemet entre -5 % et 5 %. L'indice connait des valeur plus importante notament à cause du covid en début 2020

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# En vous servant du code précédent, tracez le graphique du prix de l'autre action dans votre base de données ainsi que celui de son taux de croissance. **Commentez.**
#
# <br>
#
# </span>

# %%
df.plot(x="Date", y="Adidas", title="Évolution d'Adidas", figsize=(12, 6))
# Out:
# <Axes: title={'center': "Évolution d'Adidas"}, xlabel='Date'>

# %% [markdown]
# On remarque le même creux pour le covid debut 2020 cependaant ce qui change ici c'est la longue descente du prix de l'action a partir de mi 2021 jusqu'en fin 2022 avant une reprise d'une tendance haussière en fin 2022

# %%
df.plot(x="Date", y="rAdidas", title="Évolution de la rentabilité d'Adidas", figsize=(12, 6))
# Out:
# <Axes: title={'center': "Évolution de la rentabilité d'Adidas"}, xlabel='Date'>

# %% [markdown]
# Ici la l'évolution en taux de croissante de la valeur d'adidas est plus volatile elle est en moyenne entre -10% et 10%. Sa plus grosse chute est en 2020 avec le covid avec environ -14% et sa plus grosse hausse est d'environ 20% en fin 2022

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# Afin d'étudier l'effet de la rentabilité du DAX sur la rentabilité de l'action apparente dans votre base de données, **tracez un nuage de points et commentez.**
#
# P.S. : Vous pouvez vous servir de la formule suivante en changeant uniquement le nom de INDICE par la variable nécessaire.
# <br>
#
# </span>

# %%
# Créer le nuage
plt.figure(figsize=(12, 6))
plt.scatter(df['rDAX'], df['rAdidas'], color='blue', alpha=0.6) #a modifier

# Titre et labels
plt.title("Nuage de points entre rDAX et rAdidas") #a modifier
plt.xlabel('rDAX')
plt.ylabel('rAdidas')# a modifier
# Out:
# Text(0, 0.5, 'rAdidas')

# %% [markdown]
# #Commentaire:
#
# On remarque un gros cluster,  les valeur se concentre principalement entre -5 et 5 pour le rDAX et -5 et 10 pour rAdidas. Certaine valeur abérante deforme l'échelle. Il est possible qu'il y ait une relation croissante plutot importante entre le rDAX et rAdidas.

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
#
# <br>
#
# La matrice de corrélation de la base de données s'affiche ci-dessous:
# - Commentez les coefficients de corrélation entre les rentabilités.
# - Que pensez vous des corrélations entre les séries de rentabilité et les variables COVID et War?
# <br>
# </span>

# %%
df.drop(columns=['Date']).corr()
# Out:
#               DAX    Adidas     COVID       War      rDAX   rAdidas
# DAX      1.000000 -0.024339 -0.450576 -0.039977  0.036857  0.023386
# Adidas  -0.024339  1.000000  0.003103 -0.508325  0.018026  0.035478
# COVID   -0.450576  0.003103  1.000000 -0.159650  0.014342  0.005061
# War     -0.039977 -0.508325 -0.159650  1.000000 -0.028456 -0.052421
# rDAX     0.036857  0.018026  0.014342 -0.028456  1.000000  0.656091
# rAdidas  0.023386  0.035478  0.005061 -0.052421  0.656091  1.000000

# %% [markdown]
# #Commentaire1:
#
# La correlation entre rdax et rAdidas est de 0.656091 c'est relativement élévé.

# %% [markdown]
# #Commentaire2:
#
# la correlation entre rDAX et War négative mais faible (-0.028456 soit -2,84%) ainsi que entre rAdidas et War (-0.052421 soit -5,24%) La présence de guerre semble avoir une influence négative mais faible sur ces deux variable
#
# la correlation entre rDAX et COVID très faible (0.014342 soit 1,43%) ainsi que entre rAdidas et COVID (0.005061 soit 0.005%) La présence de guerre semble avoir une influence négative sur ces deux variable

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
#
# <br>
#
# Nous estimons le modèle de base. <br>
# $$
#                               rAdidas= \alpha + \beta_1 \cdot rDAX + \beta_2 \cdot War + \beta_3  \cdot Covid + \epsilon
# $$
# - Commentez de façon précise les résultats (significativité, qualité globale de l'ajustement).<br>
# - Commentez le signe et l'ampleur des coefficients significatifs.
#
# <br>
# </span>

# %%
import statsmodels.api as sm

df = df.dropna()
X = df[["rDAX", "War", "COVID"]]
X = sm.add_constant(X)

y = df["rAdidas"] # A MODIFIER !!!!!!!!!!!!!

modele = sm.OLS(y,X)

resultats = modele.fit()

print(resultats.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                rAdidas   R-squared:                       0.432
# Model:                            OLS   Adj. R-squared:                  0.430
# Method:                 Least Squares   F-statistic:                     320.8
# Date:                Thu, 17 Oct 2024   Prob (F-statistic):          6.31e-155
# Time:                        11:40:40   Log-Likelihood:                -2487.7
# No. Observations:                1271   AIC:                             4983.
# Df Residuals:                    1267   BIC:                             5004.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0245      0.057      0.430      0.667      -0.087       0.136
# ...

# %% [markdown]
# Le $R^2$ est de 0.432, c'est plutôt une bonne qualité d'ajustement. Cela signifie que 43,2% de la variance de la rentabilité d'Adidas ($rAdidas$) est expliqué par ce modèle

# %% [markdown]
# Nous pouvons faire un test de significativité globale de Fischer pour savoir si le modèle est significatif dans son  ensemble. On compare alors la p-value au seuil critique de 5%
# $$
# \text{Prob (F-statistic): } 6.31e-155 <0.05
# $$
# Le modèle est donc globalement significatif au sens du Fischer

# %% [markdown]
# Dans ce modèle un seul des coefficient est significatif au sens du Student si on regarde les p-value et qu'on les compare au seuil critique de 5%.
# $$
# \text{p-value}\;rDAX =   0.000
# $$
# On estime que lorque le DAX progresse de 1% Adidas progresse de 1.1276%, toutes choses étant égales par ailleurs.

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
#
# <br>
#
# <b>Résidus :</b>  <br>
#  Faites un graphique ligne des résidus. **Commentez.**
#
# <br>
# </span>

# %%
#Résidus du modèle
residus = resultats.resid

#Graphique
residus.plot()
# Out:
# <Axes: >

# %% [markdown]
# La variance n'apparait pas constante c'est a dire que l'on peut regrouper des individus par groupe avec ceux qui ont des petites variance et ceux qui ont une grosse variance. Cette anomalie prouve nous avons donc une présomption d'hétéroscédasticité

# %% [markdown]
# La présence de cluster dans les résidus peuvent également illustrer de l'autocorrelation

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
#
# <br>
#
# Afin de vérifier les hypothèses classiques de l'estimation en MCO, nous effectuons les tests d'homoscédasticité et d'autocorrélation.
#
#  **Commentez les résultats des tests.**
#
# <br>
# </span>

# %%
from statsmodels.stats.diagnostic import het_breuschpagan, het_white
from statsmodels.stats.diagnostic import acorr_breusch_godfrey

# %%
# Test hétéroscedasticité BP
stat1 = het_breuschpagan(residus, X)
print(stat1[1])
# Out:
# 0.0026801156215007925

# %% [markdown]
# La p-value (0.0026801156215007925) est inférieure ou égale à 0,05 : On rejette $H0$, selon le test de Breush Pagan nous sommes en présence d'hétéroscédasticité

# %%
# Test hétéroscedasticité W
stat2 = het_white(residus, X)
print(stat2[1])
# Out:
# 0.00010214730340947128

# %% [markdown]
# La p-value (0.00010214730340947128) est inférieure ou égale à 0,05 : On rejette $H0$, le test de White vient confirmer nos doutes, nous sommes en présence d'hétéroscédasticité

# %%
#Test d'autocorrélation
stat3 = acorr_breusch_godfrey(resultats, nlags=10)
print(stat3[1])
# Out:
# 0.003661828841230082

# %% [markdown]
# La p-value 0.003661828841230082 <  0.05 on rejette H0, nous sommes en présence d'autocorrélation

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
#
# <br>
#
# <b>Correction: </b>  <br>
# Pour remédier à ces problèmes, la méthode d'estimation de Newey-West apporte une correction aux estimateurs. Nous l'appliquons ci-dessous.
#
#  **Commentez les résultats**
#
# <br>
# </span>

# %%
resultat_robust = resultats.get_robustcov_results(cov_type='HAC', maxlags=10)
print(resultat_robust.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                rAdidas   R-squared:                       0.432
# Model:                            OLS   Adj. R-squared:                  0.430
# Method:                 Least Squares   F-statistic:                     131.0
# Date:                Thu, 17 Oct 2024   Prob (F-statistic):           6.52e-74
# Time:                        12:04:50   Log-Likelihood:                -2487.7
# No. Observations:                1271   AIC:                             4983.
# Df Residuals:                    1267   BIC:                             5004.
# Df Model:                           3
# Covariance Type:                  HAC
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0245      0.048      0.511      0.610      -0.070       0.119
# ...

# %% [markdown]
# On retrouve les mêmes estimations avec les p-value inchangé ce qui n'est pas normal. En théorie après la correction de newey west les autres variable devrait devenir significatives, ce n'est pas le cas. Le problème est donc plus profond. Il est surêment lié à la spécification du modèle : soit nous avons mal choisit nos variables, soit l'utilisation d'un modèle linéaire n'est pas adapté (le coefficient de corrélation entre radidas & rdax est élévé ce serait donc étonnant) à l'étude économétrique que nous voulons faire.
