# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
# <b><center><font size="6">Travaux Dirigés - Econométrie en finance - séance 7 </font></center></b>
#
#
#
# <g><h7><center> CM - P. Durand  - pierre.durand@u-pec.fr </center></h7></g>
#
# <g><h7><center> TD - R. Birem  - abderraouf.birem@u-pec.fr </center></h7></g>
#
#
# <b><center><font size="5">M1 - 2024-2025</font></center></b>
#
#
#
# </span>

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# <hr style=" border: 2.5px solid black;">
#
#
# <b>Objectifs de la séance : </b>
#
# - Mobilisation des outils économétrique
# - Savoir mener une étude de A à Z
#
#
# </span>

# %% [markdown]
# <hr style=" border: .5px solid black;">
# <br>
#
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
# Cette séance est axée autour de la mobilisation de l'ensemble des outils d'analyse économétrique vu en cours et en TD jusqu'à maintenant.
#
#
# <br>
#
# Cette séance est donc fondamentale puisque vous allez :
# - vérifier vos connaissances sur ce qui a été introduit depuis le début de l'année
# - vous préparer au deuxième CC
# - apprendre à mettre en place une étude du début à la fin à partir d'un notebook vierge
#
#
# <br>
#
# Nous allons travailler sur des données générées aléatoirement pour simuler des séries temporelles et mener tous les tests usuels pour finalement aboutir sur une estimation MCO.
#
# <br>
#
# Le modèle à estimer est le suivant :
#
#
# $$ y_t = \alpha + \beta_1 x1_t + \beta_2 x2_t + \epsilon_t $$
#
# <br>
#
# <hr style=" border: .5px solid black;">
#
# <br>
#
# <b>Note</b> : mettre un commentaire avec "#" dans chaque cellule de code pour spécifier ce que vous faites.
#
# <br>
#
# 1. Ouvrez un notebook vierge
# 2. Première celulle de type markdown, écrivez "# Une étude économétrique de A à Z"
#
#
# <b>Note 1 </b> : créez une celule markdown "# Importation des données"
#
#
# <br>
#
# 3. Troisième cellule : importez la base de données "data_seance6.txt".
# 4. Vérifiez que la base de données à bien été importée en affichant l'entête du dataframe
# 5. Statistiques descriptives : faites un graphqiue ligne de chaque variable (en fonction du temps).
#
#
# <b>Note 1 </b> : créez une celule markdown "# Statistiques descriptives"
#
#
# <br>
# 6. Testez la stationnarité de vos séries .
#
#
# <br>
#
# 7. Etudier les coefficients de corrélation entre les trois variables "y", "x1", et "x2".
#
# <b>Note 1 </b> : créez une celule markdown "# Analyse de la stationarité"
#
# <b>Note 2 </b> : créez une celule markdown "### nom de la variable" pour chacune des variables dont on teste la stationnairté
#
#
# <br>
#
# 8. Calculez les VIF et la statistique de Farrar-Glober pour analyser la multicolinéarité.
#
#
# <b>Note 1 </b> : créez une celule markdown "# Analyse de la multicolinéarité"
#
#
# <br>
#
#
# 9. Analysez l'hétéroscédasticité et l'autocorrélation du modèle approprié.
#
#
# <b>Note 1 </b> : créez une celule markdown "# Analyse de l'hétéroscédasticité et de l'autocorrélation"
#
#
# <br>
#
#
# 10. Estimez le modèle approprié (correction, variables etc...) et interprétez les résultats.
#
#
# <b>Note 1 </b> : créez une celule markdown "# Estimation du modèle"
#
#
# <br>
#
#
# </span>
