# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

import matplotlib.pyplot as plt

# %%
path = "C:\\Users\\issak\\Documents\\M1\\Econométrie en Banque-Finance\\data_2\\"

# %%
df = pd.read_csv(path + "base.csv", sep="*")
df.shape
df.head()
# Out:
#          Date      Adidas     Allianz       BASF      Bayer        BMW  \
# 0  2019-01-02  175.456146  128.805832  42.017372  49.486263  48.311954
# 1  2019-01-03  175.027954  127.451530  41.532982  49.437477  47.833965
# 2  2019-01-04  181.783600  130.542847  43.726574  52.771259  49.676659
# 3  2019-01-07  180.499084  129.482971  43.525902  51.933746  49.960697
# 4  2019-01-08  184.875977  129.615463  43.747334  53.275387  50.023033
#
#    Deutsche Bank  Deutsche Telekom        SAP    Siemens  Volkswagen  \
# 0       6.475192         12.327403  77.922646  72.897499   80.847702
# 1       6.428999         12.418901  75.504639  70.942757   79.957687
# 2       6.735142         12.514560  77.412178  73.722496   83.351555
# 3       6.839303         12.531196  77.573380  72.756279   83.446487
# 4       6.904517         12.364834  78.782387  73.046150   84.846764
#
#             DAX
# 0  10580.190430
# 1  10416.660156
# 2  10767.690430
# 3  10747.809570
# 4  10803.980469

# %%
df1 = df[['Adidas','Date']]
plt.rcParams['figure.figsize'] = (20,10)
df.plot(y = 'Adidas',x='Date')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,10)

plot_acf(df["Adidas"], lags=200)
plt.show()

# %%
# graphique 3
plt.rcParams['figure.figsize'] = (20,10)

plot_pacf(df["Adidas"], lags=30)
plt.show()

# %% [markdown]
# <span style='line-height:1.5;font-size: 17px;font-family:"Times New Roman"'>
#
#
#
# - Valeurs critiques de la constante et de la tendance dans le test de Dickey-Fuller
#
# <table>
#     <col width="50">
#     <col width="70">
#     <col width="70">
#     <col width="70">
#     <col width="70">
#     <col width="70">
#     <col width="70">
#     <col width="70">
#     <col width="70">
#     <col width="70">
#     <tr>
#         <td colspan="1" style="text-align: center;border-right: 2px solid black"></td>
#         <td colspan="3" style="text-align: center;border-right: 2px solid black"><i>Modèle [2]</i></td>
#         <td colspan="6" style="text-align: center;border-right: 2px solid black"><i>Modèle [1]</i></td>
#     </tr>
#     <tr>
#         <td colspan="1" style="text-align: center;border-right: 2px solid black"></td>
#         <td colspan="3" style="text-align: center;border-right: 2px solid black">Constante</td>
#         <td colspan="3" style="text-align: center;border-right: 2px solid black">Constante</td>
#         <td colspan="3" style="text-align: center;border-right: 2px solid black">Trend</td>
#     </tr>
#     <tr style="text-align: center;border-bottom: 2px solid black">
#         <td style="text-align: center;border-right: 2px solid black">T</td>
#         <td style="text-align: center;border-right: 2px dotted black">1%</td>
#         <td style="text-align: center;border-right: 2px dotted black">5%</td>
#         <td style="text-align: center;border-right: 2px solid black">10%</td>
#         <td style="text-align: center;border-right: 2px dotted black">1%</td>
#         <td style="text-align: center;border-right: 2px dotted black">5%</td>
#         <td style="text-align: center;border-right: 2px solid black">10%</td>
#         <td style="text-align: center;border-right: 2px dotted black">1%</td>
#         <td style="text-align: center;border-right: 2px dotted black">5%</td>
#         <td style="text-align: center;border-right: 2px solid black">10%</td>
#     </tr>
#     <tr>
#         <td style="text-align: center;border-right: 2px solid black">100</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.22</td>
#         <td style="text-align: center;border-right: 2px dotted black">2.54</td>
#         <td style="text-align: center;border-right: 2px solid black">2.17</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.78</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.11</td>
#         <td style="text-align: center;border-right: 2px solid black">2.73</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.53</td>
#         <td style="text-align: center;border-right: 2px dotted black">2.79</td>
#         <td style="text-align: center;border-right: 2px solid black">2.38</td>
#     </tr>
#     <tr>
#         <td style="text-align: center;border-right: 2px solid black">250</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.19</td>
#         <td style="text-align: center;border-right: 2px dotted black">2.53</td>
#         <td style="text-align: center;border-right: 2px solid black">2.16</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.74</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.09</td>
#         <td style="text-align: center;border-right: 2px solid black">2.73</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.49</td>
#         <td style="text-align: center;border-right: 2px dotted black">2.79</td>
#         <td style="text-align: center;border-right: 2px solid black">2.38</td>
#     </tr>
#     <tr>
#         <td style="text-align: center;border-right: 2px solid black">500</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.18</td>
#         <td style="text-align: center;border-right: 2px dotted black">2.52</td>
#         <td style="text-align: center;border-right: 2px solid black">2.16</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.72</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.08</td>
#         <td style="text-align: center;border-right: 2px solid black">2.72</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.48</td>
#         <td style="text-align: center;border-right: 2px dotted black">2.78</td>
#         <td style="text-align: center;border-right: 2px solid black">2.38</td>
#     </tr>
#     <tr>
#         <td style="text-align: center;border-right: 2px solid black">$\infty$</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.18</td>
#         <td style="text-align: center;border-right: 2px dotted black">2.52</td>
#         <td style="text-align: center;border-right: 2px solid black">2.16</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.71</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.08</td>
#         <td style="text-align: center;border-right: 2px solid black">2.72</td>
#         <td style="text-align: center;border-right: 2px dotted black">3.46</td>
#         <td style="text-align: center;border-right: 2px dotted black">2.78</td>
#         <td style="text-align: center;border-right: 2px solid black">2.38</td>
#     </tr>
# </table>
# </span>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adf1 = adfuller(df['Adidas'], regression='ct', autolag='AIC', regresults=True)
adf1[3].resols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     2.296
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):             0.0148
# Time:                        15:00:22   Log-Likelihood:                -3721.9
# No. Observations:                1264   AIC:                             7464.
# Df Residuals:                    1254   BIC:                             7515.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0075      0.003     -2.450      0.014      -0.013      -0.001
# x2             0.0161      0.028      0.571      0.568      -0.039       0.071
# x3            -0.0061      0.028     -0.216      0.829      -0.061       0.049
# x4            -0.0098      0.028     -0.351      0.726      -0.065       0.045
# x5             0.0201      0.028      0.716      0.474      -0.035       0.075
# x6            -0.0012      0.028     -0.041      0.967      -0.056       0.054
# x7            -0.0763      0.028     -2.717      0.007      -0.131      -0.021
# x8             0.0686      0.028      2.436      0.015       0.013       0.124
# const          2.2232      0.881      2.524      0.012       0.495       3.951
# x9            -0.0009      0.000     -2.060      0.040      -0.002   -4.38e-05
# ==============================================================================
# Omnibus:                      111.998   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              689.380
# Skew:                          -0.020   Prob(JB):                    2.01e-150
# Kurtosis:                       6.618   Cond. No.                     5.10e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.1e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# attention ici à bien changer l'option "regression" et mettre "c" au lieu de "ct"
adf1 = adfuller(df['Adidas'], regression='c', autolag='AIC', regresults=True)
adf1[3].resols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     2.048
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):             0.0381
# Time:                        15:01:50   Log-Likelihood:                -3724.1
# No. Observations:                1264   AIC:                             7466.
# Df Residuals:                    1255   BIC:                             7512.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0037      0.002     -1.512      0.131      -0.008       0.001
# x2             0.0157      0.028      0.556      0.578      -0.040       0.071
# x3            -0.0065      0.028     -0.231      0.818      -0.062       0.049
# x4            -0.0102      0.028     -0.364      0.716      -0.065       0.045
# x5             0.0197      0.028      0.702      0.483      -0.035       0.075
# x6            -0.0017      0.028     -0.059      0.953      -0.057       0.054
# x7            -0.0765      0.028     -2.723      0.007      -0.132      -0.021
# x8             0.0686      0.028      2.433      0.015       0.013       0.124
# const          0.8072      0.551      1.464      0.143      -0.274       1.889
# ==============================================================================
# Omnibus:                      110.260   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              666.613
# Skew:                          -0.001   Prob(JB):                    1.77e-145
# Kurtosis:                       6.558   Cond. No.                         960.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# attention ici à bien changer l'option "regression" et mettre "c" au lieu de "ct"
adf1 = adfuller(df['Adidas'], regression='n', autolag='AIC', regresults=True)
adf1
# Out:
# (-0.3782863742884983,
#  0.5453735904431092,
#  {'1%': -2.5675110992579313,
#   '5%': -1.941214590697016,
#   '10%': -1.6166115595542232},
#  <statsmodels.stats.diagnostic.ResultsStore at 0x1d7e60a7f50>)

# %%
df["rAdidas"] = 100 * ( df["Adidas"]/df["Adidas"].shift(1) - 1 )
df = df.dropna()
df
df2 = df[['rAdidas','Date']]
df2
# Out:
# C:\Users\issak\AppData\Local\Temp\ipykernel_21312\501202806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rAdidas"] = 100 * ( df["Adidas"]/df["Adidas"].shift(1) - 1 )
#        rAdidas        Date
# 3    -0.706618  2019-01-07
# 4     2.424883  2019-01-08
# 5    -0.231602  2019-01-09
# 6     0.851168  2019-01-10
# 7     0.767263  2019-01-11
# ...        ...         ...
# 1267 -0.775748  2023-12-21
# 1268 -5.287527  2023-12-22
# 1269  0.771159  2023-12-27
# 1270 -0.786810  2023-12-28
# 1271  0.032589  2023-12-29
#
# [1269 rows x 2 columns]

# %%
adf2 = adfuller(df2['rAdidas'], regression='ct', autolag='AIC', regresults=True)
adf2[3].resols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.501
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     113.7
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):          2.78e-179
# Time:                        15:18:18   Log-Likelihood:                -2809.4
# No. Observations:                1259   AIC:                             5643.
# Df Residuals:                    1247   BIC:                             5705.
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -1.0739      0.088    -12.143      0.000      -1.247      -0.900
# x2             0.1042      0.084      1.244      0.214      -0.060       0.269
# x3             0.0810      0.079      1.027      0.305      -0.074       0.236
# x4             0.0985      0.074      1.334      0.182      -0.046       0.243
# x5             0.1037      0.068      1.534      0.125      -0.029       0.236
# x6             0.1186      0.062      1.913      0.056      -0.003       0.240
# x7             0.0195      0.056      0.351      0.726      -0.090       0.129
# x8             0.0905      0.048      1.871      0.062      -0.004       0.185
# x9             0.0662      0.039      1.679      0.093      -0.011       0.144
# x10            0.0734      0.028      2.595      0.010       0.018       0.129
# const          0.0796      0.128      0.622      0.534      -0.171       0.331
# x11        -8.863e-05      0.000     -0.504      0.614      -0.000       0.000
# ==============================================================================
# Omnibus:                      265.957   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3825.379
# Skew:                           0.549   Prob(JB):                         0.00
# Kurtosis:                      11.469   Cond. No.                     2.13e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.13e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
adf2 = adfuller(df2['rAdidas'], regression='c', autolag='AIC', regresults=True)
adf2[3].resols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.501
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     125.1
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):          2.75e-180
# Time:                        15:19:02   Log-Likelihood:                -2809.6
# No. Observations:                1259   AIC:                             5641.
# Df Residuals:                    1248   BIC:                             5698.
# Df Model:                          10
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -1.0720      0.088    -12.136      0.000      -1.245      -0.899
# x2             0.1026      0.084      1.225      0.221      -0.062       0.267
# x3             0.0795      0.079      1.009      0.313      -0.075       0.234
# x4             0.0973      0.074      1.318      0.188      -0.048       0.242
# x5             0.1026      0.068      1.520      0.129      -0.030       0.235
# x6             0.1176      0.062      1.899      0.058      -0.004       0.239
# x7             0.0188      0.056      0.337      0.736      -0.090       0.128
# x8             0.0899      0.048      1.861      0.063      -0.005       0.185
# x9             0.0658      0.039      1.670      0.095      -0.011       0.143
# x10            0.0732      0.028      2.589      0.010       0.018       0.129
# const          0.0237      0.064      0.371      0.711      -0.102       0.149
# ==============================================================================
# Omnibus:                      264.489   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3788.684
# Skew:                           0.544   Prob(JB):                         0.00
# Kurtosis:                      11.428   Cond. No.                         13.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
adf2 = adfuller(df2['rAdidas'], regression='n', autolag='AIC', regresults=True)
adf2
# Out:
# (-12.135171876640264,
#  3.9556724640018777e-22,
#  {'1%': -2.5675181420634026,
#   '5%': -1.9412154511978623,
#   '10%': -1.6166107384252617},
#  <statsmodels.stats.diagnostic.ResultsStore at 0x1d7e610fd50>)

# %%
df1 = df[['DAX','Date']]
plt.rcParams['figure.figsize'] = (20,10)
df.plot(y = 'DAX',x='Date')
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,10)

plot_acf(df["DAX"], lags=100)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,10)

plot_pacf(df["DAX"], lags=30)
plt.show()

# %%
adf3 = adfuller(df['DAX'], regression='ct', autolag='AIC', regresults=True)
adf3[3].resols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     2.966
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):            0.00170
# Time:                        15:25:41   Log-Likelihood:                -8233.4
# No. Observations:                1261   AIC:                         1.649e+04
# Df Residuals:                    1251   BIC:                         1.654e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0123      0.004     -2.907      0.004      -0.021      -0.004
# x2            -0.0055      0.028     -0.194      0.846      -0.061       0.050
# x3             0.0360      0.028      1.281      0.200      -0.019       0.091
# x4            -0.0071      0.028     -0.254      0.799      -0.062       0.048
# x5             0.0335      0.028      1.194      0.233      -0.022       0.089
# x6             0.0625      0.028      2.222      0.026       0.007       0.118
# x7            -0.0639      0.028     -2.268      0.023      -0.119      -0.009
# x8             0.0660      0.028      2.340      0.019       0.011       0.121
# const        149.2566     50.710      2.943      0.003      49.770     248.743
# x9             0.0412      0.019      2.147      0.032       0.004       0.079
# ==============================================================================
# Omnibus:                      241.530   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2033.805
# Skew:                          -0.634   Prob(JB):                         0.00
# Kurtosis:                       9.091   Cond. No.                     1.51e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.51e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
adf3 = adfuller(df['DAX'], regression='c', autolag='AIC', regresults=True)
adf3[3].resols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     2.753
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):            0.00514
# Time:                        15:26:22   Log-Likelihood:                -8235.7
# No. Observations:                1261   AIC:                         1.649e+04
# Df Residuals:                    1252   BIC:                         1.654e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0056      0.003     -1.957      0.051      -0.011    1.27e-05
# x2            -0.0088      0.028     -0.312      0.755      -0.064       0.047
# x3             0.0330      0.028      1.173      0.241      -0.022       0.088
# x4            -0.0105      0.028     -0.374      0.709      -0.066       0.045
# x5             0.0301      0.028      1.073      0.284      -0.025       0.085
# x6             0.0590      0.028      2.100      0.036       0.004       0.114
# x7            -0.0676      0.028     -2.403      0.016      -0.123      -0.012
# x8             0.0625      0.028      2.217      0.027       0.007       0.118
# const         81.5853     39.786      2.051      0.041       3.530     159.641
# ==============================================================================
# Omnibus:                      233.312   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2044.254
# Skew:                          -0.588   Prob(JB):                         0.00
# Kurtosis:                       9.126   Cond. No.                     1.18e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
adf3 = adfuller(df['DAX'], regression='n', autolag='AIC', regresults=True)
adf3
# Out:
# (0.6656531762692868,
#  0.8601971886729418,
#  {'1%': -2.5675153182304995,
#   '5%': -1.9412151061708465,
#   '10%': -1.6166110676519616},
#  <statsmodels.stats.diagnostic.ResultsStore at 0x1d7ea684b10>)

# %%
df["rDAX"] = 100 * ( df["DAX"]/df["DAX"].shift(1) - 1 )
df["rBayer"] = 100 * ( df["Bayer"]/df["Bayer"].shift(1) - 1 )
df = df.dropna()
df
df3 = df[['rDAX','Date']]
df
# Out:
# C:\Users\issak\AppData\Local\Temp\ipykernel_21312\1565575942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rDAX"] = 100 * ( df["DAX"]/df["DAX"].shift(1) - 1 )
# C:\Users\issak\AppData\Local\Temp\ipykernel_21312\1565575942.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rBayer"] = 100 * ( df["Bayer"]/df["Bayer"].shift(1) - 1 )
#             Date      Adidas     Allianz       BASF      Bayer        BMW  \
# 11    2019-01-17  190.299500  132.662643  43.595097  52.169556  49.364925
# 12    2019-01-18  194.105484  135.430115  45.394260  54.072243  50.805832
# 13    2019-01-21  196.008484  135.724518  45.082867  53.641289  50.591080
# 14    2019-01-22  195.818192  134.929611  44.522354  53.633152  50.383266
# 15    2019-01-23  197.245438  134.900162  43.705818  53.665684  50.036896
# ...          ...         ...         ...        ...        ...        ...
# 1267  2023-12-21  193.829056  229.412308  45.238037  32.484066  93.745338
# 1268  2023-12-22  183.580292  230.314209  45.303368  32.573704  94.771782
# 1269  2023-12-27  184.995987  229.459778  45.406033  33.330650  94.545776
# 1270  2023-12-28  183.540421  228.462952  45.340702  33.355553  94.583443
# 1271  2023-12-29  183.600235  229.697113  45.527363  33.494991  94.903618
#
#       Deutsche Bank  Deutsche Telekom         SAP     Siemens  Volkswagen  \
# 11         7.048531         12.136086   81.030235   72.763718   84.787430
# 12         7.244172         12.385630   83.376602   74.740746   86.425034
# 13         7.229681         12.086177   82.364624   74.889389   85.962234
# 14         7.119179         12.094496   81.818329   73.900879   85.202759
# 15         7.221529         12.023793   82.033264   73.321152   84.407692
# ...             ...               ...         ...         ...         ...
# 1267      11.935375         20.917198  135.861237  163.815979  104.025497
# 1268      12.028651         21.037939  136.512985  163.427063  104.117996
# 1269      12.048082         20.912367  138.092987  164.146576  104.340004
# 1270      11.960638         20.878559  137.895493  163.815979  103.748001
# 1271      12.013105         21.008961  137.737488  165.216125  103.415001
#
#                DAX   rAdidas      rDAX    rBayer
# 11    10918.620117  0.959112 -0.115450 -1.413635
# 12    11205.540039  1.999997  2.627804  3.647121
# 13    11136.200195  0.980395 -0.618800 -0.796997
# 14    11090.110352 -0.097084 -0.413874 -0.015169
# 15    11071.540039  0.728863 -0.167449  0.060656
# ...            ...       ...       ...       ...
# 1267  16687.419922 -0.775748 -0.272699  0.184309
# 1268  16706.179688 -5.287527  0.112419  0.275944
# 1269  16742.070312  0.771159  0.214834  2.323796
# 1270  16701.550781 -0.786810 -0.242022  0.074713
# 1271  16751.640625  0.032589  0.299911  0.418037
#
# [1261 rows x 15 columns]

# %%
adf3 = adfuller(df3['rDAX'], regression='ct', autolag='AIC', regresults=True)
adf3[3].resols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.537
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                     58.70
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):          9.61e-184
# Time:                        15:49:01   Log-Likelihood:                -2075.2
# No. Observations:                1240   AIC:                             4200.
# Df Residuals:                    1215   BIC:                             4328.
# Df Model:                          24
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -1.0870      0.129     -8.445      0.000      -1.340      -0.834
# x2             0.0838      0.125      0.669      0.504      -0.162       0.330
# x3             0.1343      0.122      1.104      0.270      -0.104       0.373
# x4             0.1417      0.118      1.198      0.231      -0.090       0.374
# x5             0.1633      0.115      1.422      0.155      -0.062       0.389
# x6             0.2132      0.111      1.921      0.055      -0.005       0.431
# x7             0.1100      0.108      1.023      0.307      -0.101       0.321
# x8             0.1915      0.105      1.832      0.067      -0.014       0.397
# x9             0.1407      0.102      1.385      0.166      -0.059       0.340
# x10            0.1670      0.099      1.695      0.090      -0.026       0.360
# x11            0.1726      0.095      1.813      0.070      -0.014       0.359
# x12            0.2097      0.092      2.282      0.023       0.029       0.390
# x13            0.1946      0.089      2.198      0.028       0.021       0.368
# x14            0.1847      0.085      2.179      0.030       0.018       0.351
# x15            0.2130      0.081      2.640      0.008       0.055       0.371
# x16            0.2064      0.076      2.706      0.007       0.057       0.356
# x17            0.1970      0.072      2.734      0.006       0.056       0.338
# x18            0.1171      0.067      1.758      0.079      -0.014       0.248
# x19            0.0452      0.062      0.731      0.465      -0.076       0.166
# x20            0.0917      0.056      1.646      0.100      -0.018       0.201
# x21            0.0948      0.049      1.946      0.052      -0.001       0.190
# x22            0.0300      0.040      0.743      0.458      -0.049       0.109
# x23            0.0542      0.029      1.900      0.058      -0.002       0.110
# const          0.0585      0.074      0.787      0.432      -0.087       0.204
# x24        -2.102e-05      0.000     -0.203      0.839      -0.000       0.000
# ==============================================================================
# Omnibus:                      310.366   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5999.617
# Skew:                          -0.646   Prob(JB):                         0.00
# Kurtosis:                      13.698   Cond. No.                     7.65e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.65e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
adf3 = adfuller(df3['rDAX'], regression='c', autolag='AIC', regresults=True)
adf3[3].resols.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.537
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                     61.30
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):          1.24e-184
# Time:                        15:49:19   Log-Likelihood:                -2075.2
# No. Observations:                1240   AIC:                             4198.
# Df Residuals:                    1216   BIC:                             4321.
# Df Model:                          23
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -1.0864      0.129     -8.445      0.000      -1.339      -0.834
# x2             0.0832      0.125      0.664      0.507      -0.162       0.329
# x3             0.1337      0.121      1.101      0.271      -0.105       0.372
# x4             0.1412      0.118      1.195      0.233      -0.091       0.373
# x5             0.1628      0.115      1.419      0.156      -0.062       0.388
# x6             0.2127      0.111      1.918      0.055      -0.005       0.430
# x7             0.1096      0.108      1.019      0.308      -0.101       0.321
# x8             0.1910      0.104      1.829      0.068      -0.014       0.396
# x9             0.1403      0.102      1.382      0.167      -0.059       0.339
# x10            0.1666      0.098      1.692      0.091      -0.027       0.360
# x11            0.1722      0.095      1.810      0.071      -0.014       0.359
# x12            0.2093      0.092      2.279      0.023       0.029       0.389
# x13            0.1942      0.089      2.195      0.028       0.021       0.368
# x14            0.1843      0.085      2.176      0.030       0.018       0.350
# x15            0.2127      0.081      2.637      0.008       0.054       0.371
# x16            0.2060      0.076      2.703      0.007       0.057       0.356
# x17            0.1967      0.072      2.732      0.006       0.055       0.338
# x18            0.1168      0.067      1.755      0.080      -0.014       0.247
# x19            0.0449      0.062      0.728      0.467      -0.076       0.166
# x20            0.0915      0.056      1.643      0.101      -0.018       0.201
# x21            0.0946      0.049      1.943      0.052      -0.001       0.190
# x22            0.0299      0.040      0.741      0.459      -0.049       0.109
# x23            0.0541      0.028      1.898      0.058      -0.002       0.110
# const          0.0454      0.037      1.216      0.224      -0.028       0.119
# ==============================================================================
# Omnibus:                      309.263   Durbin-Watson:                   2.001
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5979.069
# Skew:                          -0.642   Prob(JB):                         0.00
# Kurtosis:                      13.681   Cond. No.                         35.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
adf3 = adfuller(df3['rDAX'], regression='n', autolag='AIC', regresults=True)
adf3
# Out:
# (-8.355790986491881,
#  5.0513678104451247e-14,
#  {'1%': -2.567545423387097,
#   '5%': -1.9412187850027065,
#   '10%': -1.6166075582369674},
#  <statsmodels.stats.diagnostic.ResultsStore at 0x1d781016890>)

# %%
df.corr()
# Out:
# C:\Users\issak\AppData\Local\Temp\ipykernel_21312\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     Adidas   Allianz      BASF     Bayer       BMW  \
# Adidas            1.000000 -0.250985  0.610273 -0.091478 -0.451752
# Allianz          -0.250985  1.000000  0.288347 -0.091339  0.880684
# BASF              0.610273  0.288347  1.000000 -0.087452  0.146317
# Bayer            -0.091478 -0.091339 -0.087452  1.000000 -0.186609
# BMW              -0.451752  0.880684  0.146317 -0.186609  1.000000
# Deutsche Bank    -0.160244  0.750480  0.411917 -0.254905  0.750711
# Deutsche Telekom -0.609335  0.817812 -0.079049 -0.094448  0.894715
# SAP               0.212535  0.534182  0.164528 -0.261289  0.428155
# Siemens          -0.205608  0.822621  0.350437 -0.312011  0.897214
# Volkswagen        0.373578  0.501160  0.786599 -0.112958  0.471996
# DAX              -0.033918  0.863100  0.483001 -0.224227  0.860972
# rAdidas           0.037115  0.028298  0.034373  0.018674  0.016499
# rDAX              0.018958  0.031024  0.053091  0.028826  0.012697
#
#                   Deutsche Bank  Deutsche Telekom       SAP   Siemens  \
# Adidas                -0.160244         -0.609335  0.212535 -0.205608
# Allianz                0.750480          0.817812  0.534182  0.822621
# BASF                   0.411917         -0.079049  0.164528  0.350437
# Bayer                 -0.254905         -0.094448 -0.261289 -0.312011
# BMW                    0.750711          0.894715  0.428155  0.897214
# Deutsche Bank          1.000000          0.643362  0.338114  0.867254
# Deutsche Telekom       0.643362          1.000000  0.337240  0.765120
# SAP                    0.338114          0.337240  1.000000  0.515604
# Siemens                0.867254          0.765120  0.515604  1.000000
# Volkswagen             0.632181          0.273985  0.298391  0.624765
# DAX                    0.864638          0.727951  0.592483  0.957250
# rAdidas                0.010744          0.011663  0.058717  0.021928
# rDAX                   0.032708          0.017723  0.047691  0.030833
#
#                   Volkswagen       DAX   rAdidas      rDAX
# Adidas              0.373578 -0.033918  0.037115  0.018958
# Allianz             0.501160  0.863100  0.028298  0.031024
# BASF                0.786599  0.483001  0.034373  0.053091
# Bayer              -0.112958 -0.224227  0.018674  0.028826
# BMW                 0.471996  0.860972  0.016499  0.012697
# Deutsche Bank       0.632181  0.864638  0.010744  0.032708
# Deutsche Telekom    0.273985  0.727951  0.011663  0.017723
# SAP                 0.298391  0.592483  0.058717  0.047691
# Siemens             0.624765  0.957250  0.021928  0.030833
# Volkswagen          1.000000  0.739291  0.003968  0.022832
# DAX                 0.739291  1.000000  0.027905  0.039707
# rAdidas             0.003968  0.027905  1.000000  0.655680
# rDAX                0.022832  0.039707  0.655680  1.000000

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor as VIF

# %%
l_explicatives =  ['rAdidas','rBayer'] 
for n,var in enumerate(l_explicatives):
    print('le VIF de la variable', var, ' est : ',VIF(df[l_explicatives].dropna().values,n))
# Out:
# le VIF de la variable rAdidas  est :  1.1362310457480396
# le VIF de la variable rBayer  est :  1.1362310457480398

# %%
import numpy as np
from numpy.linalg import det

# %%
D = det(df[l_explicatives].corr())

#(1/2 k(k+1)) 
    # calcul de la stat : T=1261 et k=2
FG = -(1261 - (1/6) * (2*(2+1))+3)*np.log(D)
print(FG)
# Out:
# 161.41872119042097

# %%
import statsmodels.api as sm
X = df[ ['rAdidas','rBayer']].dropna()
X = sm.add_constant(X)
y = df["DAX"].dropna()
modele2 = sm.OLS(y,X)
resultats2 = modele2.fit()
print(resultats2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    DAX   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.5449
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):              0.580
# Time:                        15:55:48   Log-Likelihood:                -11139.
# No. Observations:                1261   AIC:                         2.228e+04
# Df Residuals:                    1258   BIC:                         2.230e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.387e+04     46.788    296.520      0.000    1.38e+04     1.4e+04
# rAdidas       18.3176     21.898      0.836      0.403     -24.644      61.279
# rBayer         7.3971     24.979      0.296      0.767     -41.609      56.403
# ==============================================================================
# Omnibus:                       71.489   Durbin-Watson:                   0.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.951
# Skew:                          -0.341   Prob(JB):                     1.05e-10
# Kurtosis:                       2.361   Cond. No.                         2.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
residus2=resultats2.resid
plt.plot(residus2)

# %%
from statsmodels.stats.diagnostic import het_breuschpagan, het_white

# %%
bp = het_breuschpagan(residus2, X)
print(bp)
# Out:
# (0.15413178573219066, 0.9258288460803551, 0.07689194664439282, 0.9259942561573173)

# %%
from statsmodels.stats.diagnostic import acorr_breusch_godfrey

# %%
bg = acorr_breusch_godfrey(resultats2) 
print(bg)
# Out:
# (1251.6374879636755, 1.0440856358771171e-262, 16684.0221824909, 0.0)

# %%
resultat_robust2 = resultats2.get_robustcov_results(cov_type='HAC', maxlags=10)
print(resultat_robust2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    DAX   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.3527
# Date:                Wed, 27 Nov 2024   Prob (F-statistic):              0.703
# Time:                        16:04:13   Log-Likelihood:                -11139.
# No. Observations:                1261   AIC:                         2.228e+04
# Df Residuals:                    1258   BIC:                         2.230e+04
# Df Model:                           2
# Covariance Type:                  HAC
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.387e+04    152.913     90.729      0.000    1.36e+04    1.42e+04
# rAdidas       18.3176     24.005      0.763      0.446     -28.777      65.413
# rBayer         7.3971     29.877      0.248      0.804     -51.218      66.012
# ==============================================================================
# Omnibus:                       71.489   Durbin-Watson:                   0.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.951
# Skew:                          -0.341   Prob(JB):                     1.05e-10
# Kurtosis:                       2.361   Cond. No.                         2.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 10 lags and without small sample correction
